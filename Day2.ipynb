# %%
radius=float(input("Enter a radius"))
area=3.14*radius**2
print("Area of cirlce=",area)
# Out:
# Enter a radius2
# Area of cirlce= 12.56

# %%
p=int(input("enter a price="))
r=int(input("enter a rate="))
t=int(input("enter a time="))
si=(p*r*t)/100
print("Simple intrest=",si)
# Out:
# enter a price=34
# enter a rate=56
# enter a time=2
# Simple intrest= 38.08

# %%
a=int(input("enter a number="))
even=a%2==0
odd=a%2!=0
print("even",even)
print("odd=",odd)
# Out:
# enter a number=2
# even True
# odd= False

# %%
a=int(input("Enter a nummber="))
b=int(input('Enter a nnumber='))
largest=a>b
print(largest)
# Out:
# Enter a nummber=5
# Enter a nnumber=3
# True

# %%
c=float(input("Enter a temprature in celcius="))
f=(c*9/5)+32
print("Temprature in farenhite=",f)
# Out:
# Enter a temprature in celcius=28
# Temprature in farenhite= 82.4
